# %% [markdown]
# <a href="https://colab.research.google.com/github/SteveRiddle/CollabExamples/blob/main/Maths_colab_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab
# Trying out some simple Maths functions

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-10,10,100)
plt.plot(x, x**2)
plt.title("Square ")
# Out:
# Text(0.5, 1.0, 'Square ')

# %% [markdown]
# Some examples from notes

# %%
x=np.linspace(5,-1, endpoint=False)
y=1/(np.sqrt(x +1) )
plt.plot(x, y)
plt.title("Function example")
# Out:
# Text(0.5, 1.0, 'Function example')
